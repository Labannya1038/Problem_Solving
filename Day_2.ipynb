# %% [markdown]
# <a href="https://colab.research.google.com/github/Labannya1038/Problem_Solving/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **List**-represent with [] bracket

# %%
A = ['Labannya',5,5.2,True]

# %%
type(A)
# Out:
# list

# %%
print(A)
# Out:
# ['Labannya', 5, 5.2, True]

# %%
B = [["Labannya" , "Barua"],[5,10]] #list of list

# %%
matrix = [1,2,3] , [4,5,6] , [7,8,9]

# %%
matrix
# Out:
# ([1, 2, 3], [4, 5, 6], [7, 8, 9])

# %%
D = A + B

# %%
print(D)
# Out:
# ['Labannya', 5, 5.2, True, ['Labannya', 'Barua'], [5, 10]]

# %%
type(D)
# Out:
# list

# %% [markdown]
# **-We add more element by using extend() function.**

# %%
A.append(7)

# %%
print(A)
# Out:
# ['Labannya', 5, 5.2, True, 7]

# %%
id = [ 29,38,34]

# %%
id.append(31)

# %%
print(id)
# Out:
# [29, 38, 34, 31]

# %% [markdown]
# **-We can Change List element.**

# %%
name = ['abc' , 'Barua']

# %%
name
# Out:
# ['abc', 'Barua']

# %%
name[0] ='Labannya'

# %%
name
# Out:
# ['Labannya', 'Barua']

# %%
name[1] = 'Premier'

# %%
name
# Out:
# ['Labannya', 'Premier']

# %% [markdown]
# **-We can delete an element from list.**

# %%
del(name[1])

# %%
name
# Out:
# ['Labannya']

# %% [markdown]
# **-Convert string to list using split().**

# %%
paper1 = "Attention Is All You Need"

# %%
type(paper1)
# Out:
# str

# %%
paper = paper1.split()

# %%
paper
# Out:
# ['Attention', 'Is', 'All', 'You', 'Need']

# %%
paper = paper1.split('1')

# %%
paper
# Out:
# ['Attention Is All You Need']

# %%
paper = paper1.split()

# %%
type(paper)
# Out:
# list

# %%
'Attention Is'.split()
# Out:
# ['Attention', 'Is']

# %%
'Attention , Is'.split(",")
# Out:
# ['Attention ', ' Is']

# %%
'Attention , Is All You Need'.split(",")
# Out:
# ['Attention ', ' Is All You Need']

# %% [markdown]
# # **List Index**

# %%
word = ["a", "b", "c", ["d", "e"], "f"]

# %% [markdown]
# **-Print 3rd element from the list.**

# %%
word[2]
# Out:
# 'c'

# %%
word[-3]
# Out:
# 'c'

# %% [markdown]
# **-Print 4th element from the list.**

# %%
word[3]
# Out:
# ['d', 'e']

# %%
word[3][0]
# Out:
# 'd'

# %%
word[3][1]
# Out:
# 'e'

# %% [markdown]
# - Print 1st to 3rd value from the list.
#
# - syntax: my_list[start:end]
#
# - end value not included

# %%
word[0:3]
# Out:
# ['a', 'b', 'c']

# %%
word[1:3]
# Out:
# ['b', 'c']

# %% [markdown]
# **-We can add two string or sum two values.**

# %%
num = [5,10,15,20,25]

# %%
num[0]+ num[4]
# Out:
# 30

# %%
word[0] + word[4]
# Out:
# 'af'

# %% [markdown]
# - Copy list
#
# - If we change one element from any of list than the both list are changes.

# %%
x = num

# %%
x
# Out:
# [5, 10, 15, 20, 25]

# %%
num.append(30)

# %%
x
# Out:
# [5, 10, 15, 20, 25, 30]

# %% [markdown]
# - Colon list
#
# - Every list act as indivual list.

# %%
Y = num[:]

# %%
Y
# Out:
# [5, 10, 15, 20, 25, 30]

# %%
num.append(50)

# %%
Y
# Out:
# [5, 10, 15, 20, 25, 30]

# %% [markdown]
# # **List Method**
#
# - append() Adds an element at the end of the list
#
# - clear() Removes all the elements from the list
#
# - copy() Returns a copy of the list
#
# - count() Returns the number of elements with the specified value
#
# - extend() Add the elements of a list (or any iterable), to the end of the current list
#
# - index() Returns the index of the first element with the specified value
#
# - insert() Adds an element at the specified position
#
# - pop() Removes the element at the specified position
#
# - remove() Removes the item with the specified value
#
# - reverse() Reverses the order of the list
#
# - sort() Sorts the list

# %%
list_1 = [1,2,3]

# %%
list_1.append(4)

# %%
list_1
# Out:
# [1, 2, 3, 4]

# %%
list_1.clear() #clear() Removes all the elements from the list

# %%
list_1
# Out:
# []

# %%
list_2 = ["a", "b", "c"]

# %%
list_3 = list_2.copy() #copy() Returns a copy of the list

# %%
list_3
# Out:
# ['a', 'b', 'c']

# %%
list_3.append("d") #In copy method. If we change one element from a list, Other list doesn't change.

# %%
list_3
# Out:
# ['a', 'b', 'c', 'd']

# %%
list_4 = [1,3,2,4,5,6,4,5,7,6,5,8,5]

# %%
list_4.count(5) #count() Returns the number of elements with the specified value.
# Out:
# 4

# %%
list_3.extend('e') #extend() Add the elements of a list (or any iterable), to the end of the current list

# %%
list_3
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
list_3.index('d') #index() Returns the index of the first element with the specified value
# Out:
# 3

# %% [markdown]
# - insert() Adds an element at the specified position
# - Syntax: list.insert(position, element)

# %%
list_3.insert(4,'abc')

# %%
list_3
# Out:
# ['a', 'b', 'c', 'd', 'abc', 'e']

# %% [markdown]
# - pop() Removes the element at the specified position
# - Syntax: list.pop(position)

# %%
list_3.pop(2)
# Out:
# 'c'

# %%
list_3
# Out:
# ['a', 'b', 'd', 'abc', 'e']

# %% [markdown]
# - remove() Removes the item with the specified value
# - Syntax: list.remove(element)

# %%
list_3.remove('abc')

# %%
list_3
# Out:
# ['a', 'b', 'd', 'e']

# %%
list_3.reverse() #reverse() Reverses the order of the list

# %%
list_3
# Out:
# ['e', 'd', 'b', 'a']

# %%
list_3.sort() #sort() Sorts the list

# %%
list_3
# Out:
# ['a', 'b', 'd', 'e']
